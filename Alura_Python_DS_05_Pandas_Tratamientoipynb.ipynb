# %% [markdown]
# <a href="https://colab.research.google.com/github/Cesarpipe31/Alura_Python_DS_05_Pandas_Tratamiento_Publicar/blob/main/Alura_Python_DS_05_Pandas_Tratamientoipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -V
# Out:
# Python 3.10.12

# %%
import pandas as pd
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 12)

# %%
dataset = pd.read_csv('alquiler.csv', sep = ';')

# %%
dataset
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# ...

# %%
dataset.describe()
# Out:
#             Cuartos      Vacantes        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#        Mantenimiento      Impuesto
# count   2.886700e+04  2.272300e+04
# mean    2.388062e+03  2.364410e+03
# std     3.918496e+04  1.795641e+05
# min     1.000000e+00  1.000000e+00
# 25%     5.900000e+02  1.100000e+02
# 50%     9.900000e+02  2.500000e+02
# ...

# %% [markdown]
# # **Parte 2:  Importando Datos**

# %%
import pandas as pd

# %%
datos = pd.read_csv('alquiler.csv', sep = ';')

# %%
datos
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           32960 non-null  object
#  1   Distrito       32960 non-null  object
#  2   Cuartos        32960 non-null  int64
#  3   Vacantes       32960 non-null  int64
#  4   Suites         32960 non-null  int64
#  5   Area           32960 non-null  int64
#  6   Valor          32943 non-null  float64
#  7   Mantenimiento  28867 non-null  float64
#  8   Impuesto       22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
datos
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# ...

# %%
datos.head()
# Out:
#               Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0       Habitación   San Borja        1         0       0    40  1700.0
# 1             Casa  Lurigancho        2         0       1   100  7000.0
# 2  Local comercial         Ate        0         4       0   150  5200.0
# 3     Departamento  Pachacámac        1         0       0    15   800.0
# 4     Departamento         Ate        1         0       0    48   800.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# 4          230.0       NaN

# %%
datos.head(7)
# Out:
#               Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0       Habitación   San Borja        1         0       0    40  1700.0
# 1             Casa  Lurigancho        2         0       1   100  7000.0
# 2  Local comercial         Ate        0         4       0   150  5200.0
# 3     Departamento  Pachacámac        1         0       0    15   800.0
# 4     Departamento         Ate        1         0       0    48   800.0
# 5     Departamento    Barranco        3         1       0    70  1200.0
# 6     Departamento       Comas        2         0       0    50  1300.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# 4          230.0       NaN
# 5            NaN       NaN
# 6          301.0      17.0

# %% [markdown]
# ## Informaciones generales sobre la Base de Datos

# %%
datos.dtypes
# Out:
# Tipo              object
# Distrito          object
# Cuartos            int64
# Vacantes           int64
# Suites             int64
# Area               int64
# Valor            float64
# Mantenimiento    float64
# Impuesto         float64
# dtype: object

# %%
tipo_de_datos = pd.DataFrame(datos.dtypes, columns = ['Tipos de Datos'])

# %%
tipo_de_datos
# Out:
#               Tipos de Datos
# Tipo                  object
# Distrito              object
# Cuartos                int64
# Vacantes               int64
# Suites                 int64
# Area                   int64
# Valor                float64
# Mantenimiento        float64
# Impuesto             float64

# %%
tipo_de_datos.columns.name = 'Variables'

# %%
tipo_de_datos
# Out:
# Variables     Tipos de Datos
# Tipo                  object
# Distrito              object
# Cuartos                int64
# Vacantes               int64
# Suites                 int64
# Area                   int64
# Valor                float64
# Mantenimiento        float64
# Impuesto             float64

# %%
datos.shape
# Out:
# (32960, 9)

# %%
datos.shape[0]
# Out:
# 32960

# %%
datos.shape[1]
# Out:
# 9

# %%
print('La base de datos presenta {} registros (inmuebles) y {} variables'.format(datos.shape[0], datos.shape[1]))
# Out:
# La base de datos presenta 32960 registros (inmuebles) y 9 variables

# %%
#Ejercicio Evaluativo en Alura

import pandas as pd

data = [['Fulano', 12, 7.0, True],
        ['Sicrano', 15, 3.5, False],
        ['Beltrano', 18, 9.3, True]]

datos = pd.DataFrame(data,
        columns = ['Alumno', 'Edad', 'Nota', 'Aprobado'])

datos
# Out:
#      Alumno  Edad  Nota  Aprobado
# 0    Fulano    12   7.0      True
# 1   Sicrano    15   3.5     False
# 2  Beltrano    18   9.3      True

# %%
#Ejercicio Evaluativo en Alura

tipos_de_datos = pd.DataFrame(datos.dtypes, columns = ['Tipos de Datos'])
tipos_de_datos.columns.name = 'Variables'
tipos_de_datos
# Out:
# Variables Tipos de Datos
# Alumno            object
# Edad               int64
# Nota             float64
# Aprobado            bool

# %% [markdown]
# # **Importando bases de datos**

# %%
import pandas as pd

# %% [markdown]
# ## Abrir JSON

# %%
json = open('datos/alquiler.json')

# %%
print(json.read())
# Out:
# [{"Tipo":"Habitación","Distrito":"San Borja","Cuartos":1,"Vacantes":0,"Suites":0,"Area":40,"Valor":1700.0,"Mantenimiento":500.0,"Impuesto":60.0},
# {"Tipo":"Casa","Distrito":"Lurigancho","Cuartos":2,"Vacantes":0,"Suites":1,"Area":100,"Valor":7000.0,"Mantenimiento":null,"Impuesto":null},
# {"Tipo":"Local comercial","Distrito":"Ate","Cuartos":0,"Vacantes":4,"Suites":0,"Area":150,"Valor":5200.0,"Mantenimiento":4020.0,"Impuesto":1111.0},
# {"Tipo":"Departamento","Distrito":"Pachacámac","Cuartos":1,"Vacantes":0,"Suites":0,"Area":15,"Valor":800.0,"Mantenimiento":390.0,"Impuesto":20.0},
# {"Tipo":"Departamento","Distrito":"Ate","Cuartos":1,"Vacantes":0,"Suites":0,"Area":48,"Valor":800.0,"Mantenimiento":230.0,"Impuesto":null},
# {"Tipo":"Departamento","Distrito":"Barranco","Cuartos":3,"Vacantes":1,"Suites":0,"Area":70,"Valor":1200.0,"Mantenimiento":null,"Impuesto":null},
# ...

# %%
df_json = pd.read_json('datos/alquiler.json')

# %%
df_json
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %% [markdown]
# ## Abrir TXT

# %%
txt = open('datos/alquiler.txt')
print(txt.read())
# Out:
# Tipo	Distrito	Cuartos	Vacantes	Suites	Area	Valor	Mantenimiento	Impuesto
# Habitación	San Borja	1	0	0	40	1700	500	60
# Casa	Lurigancho	2	0	1	100	7000
# Local comercial	Ate	0	4	0	150	5200	4020	1111
# Departamento	Pachacámac	1	0	0	15	800	390	20
# Departamento	Ate	1	0	0	48	800	230
# Departamento	Barranco	3	1	0	70	1200
# Departamento	Comas	2	0	0	50	1300	301	17
# Casa en condominio	Ate	5	4	5	750	22000
# Casa en condominio	El Agustino	2	2	0	65	1000
# Local comercial	Pachacámac	0	3	0	695	35000	19193	3030

# %%
df_txt = pd.read_table('datos/alquiler.txt')

# %%
df_txt
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %% [markdown]
# ## Abril XLSX

# %%
df_xlsx = pd.read_excel('datos/alquiler.xlsx')

# %%
df_xlsx
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %% [markdown]
# ## Abrir HTML

# %%
df_html = pd.read_html('datos/datos_html_1.html')

# %%
df_html
# Out:
# [     Año                           Campeón                        Subcampeón  \
#  0   2018                           Francia                           Croacia
#  1   2014                          Alemania                         Argentina
#  2   2010                            España                           Holanda
#  3   2006                            Italia                           Francia
#  4   2002                            Brasil                          Alemania
#  ..   ...                               ...                               ...
#  18  1946  No celebrado (II Guerra Mundial)  No celebrado (II Guerra Mundial)
#  19  1942  No celebrado (II Guerra Mundial)  No celebrado (II Guerra Mundial)
#  20  1938                            Italia                           Hungría
#  21  1934                            Italia                    Checoslovaquia
#  22  1930                           Uruguay                         Argentina
#
# ...

# %%
df_html[0]
# Out:
#      Año                           Campeón                        Subcampeón  \
# 0   2018                           Francia                           Croacia
# 1   2014                          Alemania                         Argentina
# 2   2010                            España                           Holanda
# 3   2006                            Italia                           Francia
# 4   2002                            Brasil                          Alemania
# ..   ...                               ...                               ...
# 18  1946  No celebrado (II Guerra Mundial)  No celebrado (II Guerra Mundial)
# 19  1942  No celebrado (II Guerra Mundial)  No celebrado (II Guerra Mundial)
# 20  1938                            Italia                           Hungría
# 21  1934                            Italia                    Checoslovaquia
# 22  1930                           Uruguay                         Argentina
#
#                                 Sede
# ...

# %%
df_html1 = pd.read_html('https://www.banrep.gov.co/es/estadisticas/trm')

# %%
df_html1
# Out:
# [           0       1       2
#  0        NaN     NaN     NaN
#  1  DIC 13-19  DIC 19  DIC 22,
#             0       1       2
#  0        NaN     NaN     NaN
#  1  DIC 13-19  DIC 19  DIC 22,
#                                                     0  \
#  0                                          Encuestas
#  1  MIÉRCOLES, 3 AGOSTO 2022  Divulgación de la En...
#  2  JUEVES, 21 JULIO 2022  Divulgación de la Encue...
#
#                                                     1
#  0                                          Encuestas
#  1  LUNES, 1 AGOSTO 2022  Divulgación de reportes ...
#  2  VIERNES, 15 JULIO 2022  Divulgación de la Encu...  ,
#      0   1   2   3
#  0 NaN NaN NaN NaN,
#             0       1       2
#  0        NaN     NaN     NaN
#  1  DIC 13-19  DIC 19  DIC 22,
#             0       1       2
#  0        NaN     NaN     NaN
#  1  DEC 13-19  DEC 19  DEC 22,
#                                                     0  \
# ...

# %%
len(df_html1)
# Out:
# 10

# %%
df_html1[0]
# Out:
#            0       1       2
# 0        NaN     NaN     NaN
# 1  DIC 13-19  DIC 19  DIC 22

# %%
df_html1[1]
# Out:
#            0       1       2
# 0        NaN     NaN     NaN
# 1  DIC 13-19  DIC 19  DIC 22

# %%
df_html1[2]
# Out:
#                                                    0  \
# 0                                          Encuestas
# 1  MIÉRCOLES, 3 AGOSTO 2022  Divulgación de la En...
# 2  JUEVES, 21 JULIO 2022  Divulgación de la Encue...
#
#                                                    1
# 0                                          Encuestas
# 1  LUNES, 1 AGOSTO 2022  Divulgación de reportes ...
# 2  VIERNES, 15 JULIO 2022  Divulgación de la Encu...

# %%
df_html1[3]
# Out:
#     0   1   2   3
# 0 NaN NaN NaN NaN

# %%
df_html1[4]
# Out:
#            0       1       2
# 0        NaN     NaN     NaN
# 1  DIC 13-19  DIC 19  DIC 22

# %%
df_html1[5]
# Out:
#            0       1       2
# 0        NaN     NaN     NaN
# 1  DEC 13-19  DEC 19  DEC 22

# %%
df_html1[6]
# Out:
#                                                    0  \
# 0                          Surveys (only in Spanish)
# 1  WEDNESDAY, 3 AUGUST 2022  Dissemination of the...
# 2  THURSDAY, 21 JULY 2022  Dissemination of the M...
#
#                                                    1
# 0                          Surveys (only in Spanish)
# 1  MONDAY, 1 AUGUST 2022  Dissemination of Financ...
# 2  FRIDAY, 15 JULY 2022  Dissemination of the Mon...

# %%
df_html1[7]
# Out:
#     0   1
# 0 NaN NaN

# %%
df_html1[8]
# Out:
#     0   1
# 0 NaN NaN

# %%
df_html1[9]
# Out:
#                                                    0  \
# 0                                          Encuestas
# 1  MARTES 22 MARZO 2022  Divulgación de la Encues...
# 2  MIÉRCOLES 02 MARZO 2022  Divulgación de la Enc...
#
#                                                    1
# 0                                          Encuestas
# 1  MARTES 15 MARZO 2022  Divulgación de la Encues...
# 2  LUNES 21 FEBRERO 2022  Divulgación de la Encue...

# %% [markdown]
# # **Parte 3:  Series e Index**

# %%
import pandas as pd

# %%
datos = pd.read_csv('alquiler.csv', sep = ';')

# %%
datos
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# ...

# %%
datos['Tipo']
# Out:
# 0             Habitación
# 1                   Casa
# 2        Local comercial
# 3           Departamento
# 4           Departamento
#               ...
# 32955         Habitación
# 32956       Departamento
# 32957       Departamento
# 32958       Departamento
# 32959    Local comercial
# Name: Tipo, Length: 32960, dtype: object

# %%
datos.Tipo
# Out:
# 0             Habitación
# 1                   Casa
# 2        Local comercial
# 3           Departamento
# 4           Departamento
#               ...
# 32955         Habitación
# 32956       Departamento
# 32957       Departamento
# 32958       Departamento
# 32959    Local comercial
# Name: Tipo, Length: 32960, dtype: object

# %%
tipo_de_inmueble = datos.Tipo

# %%
type(tipo_de_inmueble)
# Out:
# pandas.core.series.Series

# %%
tipo_de_inmueble.drop_duplicates()
# Out:
# 0                Habitación
# 1                      Casa
# 2           Local comercial
# 3              Departamento
# 7        Casa en condominio
#                 ...
# 4379                Oficina
# 4721                 Chalet
# 6983                 Studio
# 9687                  Hotel
# 23614      Local industrial
# Name: Tipo, Length: 22, dtype: object

# %%
tipo_de_inmueble
# Out:
# 0             Habitación
# 1                   Casa
# 2        Local comercial
# 3           Departamento
# 4           Departamento
#               ...
# 32955         Habitación
# 32956       Departamento
# 32957       Departamento
# 32958       Departamento
# 32959    Local comercial
# Name: Tipo, Length: 32960, dtype: object

# %%
tipo_de_inmueble.drop_duplicates(inplace = True)

# %%
tipo_de_inmueble
# Out:
# 0                Habitación
# 1                      Casa
# 2           Local comercial
# 3              Departamento
# 7        Casa en condominio
#                 ...
# 4379                Oficina
# 4721                 Chalet
# 6983                 Studio
# 9687                  Hotel
# 23614      Local industrial
# Name: Tipo, Length: 22, dtype: object

# %%
## Video 4 redefiniendo el Index
